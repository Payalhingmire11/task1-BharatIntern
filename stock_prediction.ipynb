# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_set = pd.read_csv('NSE-TA~1.CSV')
data_set
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-10-08  208.00  222.25  206.85  216.00  215.15
# 1     2018-10-05  217.00  218.60  205.90  210.25  209.20
# 2     2018-10-04  223.50  227.80  216.15  217.25  218.20
# 3     2018-10-03  230.00  237.50  225.75  226.45  227.60
# 4     2018-10-01  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  2013-10-14  160.85  161.45  157.70  159.30  159.45
# 1231  2013-10-11  161.15  163.45  159.00  159.80  160.05
# 1232  2013-10-10  156.00  160.80  155.85  160.30  160.15
# 1233  2013-10-09  155.70  158.20  154.15  155.30  155.55
# 1234  2013-10-08  157.00  157.80  155.20  155.80  155.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                4642146.0         10062.83
# 1                3519515.0          7407.06
# 2                1728786.0          3815.79
# 3                1708590.0          3960.27
# 4                1534749.0          3486.05
# ...                    ...              ...
# 1230             1281419.0          2039.09
# 1231             1880046.0          3030.76
# 1232             3124853.0          4978.80
# 1233             2049580.0          3204.49
# 1234             1720413.0          2688.94
#
# [1235 rows x 8 columns]

# %%
data_set.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    168.954858   171.429069   166.402308   168.736356   168.731053
# std      51.499145    52.436761    50.542919    51.587384    51.544928
# min     103.000000   104.600000   100.000000   102.600000   102.650000
# 25%     137.550000   138.925000   135.250000   137.175000   137.225000
# 50%     151.500000   153.250000   149.500000   151.200000   151.100000
# 75%     169.000000   172.325000   166.700000   169.100000   169.500000
# max     327.700000   328.750000   321.650000   325.950000   325.750000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.235000e+03      1235.000000
# mean           2.604151e+06      4843.166502
# std            2.277028e+06      5348.919832
# min            1.001800e+05       128.040000
# 25%            1.284482e+06      1801.035000
# 50%            1.964885e+06      3068.510000
# 75%            3.095788e+06      5852.600000
# max            2.919102e+07     55755.080000

# %%
data_set.tail()
# Out:
#             Date    Open    High     Low   Last   Close  Total Trade Quantity  \
# 1230  2013-10-14  160.85  161.45  157.70  159.3  159.45             1281419.0
# 1231  2013-10-11  161.15  163.45  159.00  159.8  160.05             1880046.0
# 1232  2013-10-10  156.00  160.80  155.85  160.3  160.15             3124853.0
# 1233  2013-10-09  155.70  158.20  154.15  155.3  155.55             2049580.0
# 1234  2013-10-08  157.00  157.80  155.20  155.8  155.80             1720413.0
#
#       Turnover (Lacs)
# 1230          2039.09
# 1231          3030.76
# 1232          4978.80
# 1233          3204.49
# 1234          2688.94

# %%
data_set.dtypes
# Out:
# Date                     object
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity    float64
# Turnover (Lacs)         float64
# dtype: object

# %%
data_set['Date'].value_counts()
# Out:
# 2018-10-08    1
# 2015-06-15    1
# 2015-06-04    1
# 2015-06-05    1
# 2015-06-08    1
#              ..
# 2017-02-09    1
# 2017-02-10    1
# 2017-02-13    1
# 2017-02-14    1
# 2013-10-08    1
# Name: Date, Length: 1235, dtype: int64

# %%
data_set['High'].hist()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,8))
data_set.plot()
# Out:
# <Axes: >

# %%
data=data_set.filter(['Close'])
dataset = data_set.values
training_data_len=math.ceil(len(data_set)*8)
training_data_len
# Out:
# 9880

# %%
dataset
# Out:
# array([['2018-10-08', 208.0, 222.25, ..., 215.15, 4642146.0, 10062.83],
#        ['2018-10-05', 217.0, 218.6, ..., 209.2, 3519515.0, 7407.06],
#        ['2018-10-04', 223.5, 227.8, ..., 218.2, 1728786.0, 3815.79],
#        ...,
#        ['2013-10-10', 156.0, 160.8, ..., 160.15, 3124853.0, 4978.8],
#        ['2013-10-09', 155.7, 158.2, ..., 155.55, 2049580.0, 3204.49],
#        ['2013-10-08', 157.0, 157.8, ..., 155.8, 1720413.0, 2688.94]],
#       dtype=object)

# %%
data_set= data_set.iloc[:, 0:5]
data_set
# Out:
#             Date    Open    High     Low    Last
# 0     2018-10-08  208.00  222.25  206.85  216.00
# 1     2018-10-05  217.00  218.60  205.90  210.25
# 2     2018-10-04  223.50  227.80  216.15  217.25
# 3     2018-10-03  230.00  237.50  225.75  226.45
# 4     2018-10-01  234.55  234.60  221.05  230.30
# ...          ...     ...     ...     ...     ...
# 1230  2013-10-14  160.85  161.45  157.70  159.30
# 1231  2013-10-11  161.15  163.45  159.00  159.80
# 1232  2013-10-10  156.00  160.80  155.85  160.30
# 1233  2013-10-09  155.70  158.20  154.15  155.30
# 1234  2013-10-08  157.00  157.80  155.20  155.80
#
# [1235 rows x 5 columns]

# %%
training_set = data_set.iloc[:,1:2].values
training_set
# Out:
# array([[208. ],
#        [217. ],
#        [223.5],
#        ...,
#        [156. ],
#        [155.7],
#        [157. ]])

# %% [markdown]
# # SCALING OF DATA_SET

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_scaled = scaler.fit_transform(training_set)

# %%
features_set = []
labels = []
for i in range(60, 586):
    features_set.append(data_training_scaled[i-60:i, 0])
    labels.append(data_training_scaled[i, 0])

# %%
features_set, labels = np.array(features_set), np.array(labels)

# %%
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))
features_set.shape
# Out:
# (526, 60, 1)

# %% [markdown]
# # BUILDING A LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
model = Sequential()

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.fit(features_set, labels, epochs = 30, batch_size = 20)
# Out:
# Epoch 1/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1514
# Epoch 2/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1517
# Epoch 3/30
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1528
# Epoch 4/30
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1535
# Epoch 5/30
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1483
# Epoch 6/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1523
# Epoch 7/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1581
# Epoch 8/30
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1505
# Epoch 9/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1536
# Epoch 10/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1532
# Epoch 11/30
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1546
# Epoch 12/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1546
# Epoch 13/30
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1547
# Epoch 14/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1549
# Epoch 15/30
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1537
# Epoch 16/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1545
# Epoch 17/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1566
# Epoch 18/30
# 27/27 [==============================] - 0s 1ms/step - loss: 0.1532
# Epoch 19/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1539
# Epoch 20/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1548
# Epoch 21/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1521
# Epoch 22/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1552
# Epoch 23/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1563
# Epoch 24/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1537
# Epoch 25/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1536
# Epoch 26/30
# 27/27 [==============================] - 0s 14ms/step - loss: 0.1551
# Epoch 27/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1550
# Epoch 28/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1509
# Epoch 29/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1554
# Epoch 30/30
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1524

# %%
data_testing_complete = pd.read_csv('NSE-TA~1.CSV')
data_testing_processed = data_testing_complete.iloc[:, 1:2]
data_testing_processed
# Out:
#         Open
# 0     208.00
# 1     217.00
# 2     223.50
# 3     230.00
# 4     234.55
# ...      ...
# 1230  160.85
# 1231  161.15
# 1232  156.00
# 1233  155.70
# 1234  157.00
#
# [1235 rows x 1 columns]

# %% [markdown]
# # PREDICTION OF THE DATA

# %%
data_total = pd.concat((data_set['Open'], data_set['Open']), axis=0)

# %%
test_inputs = data_total[len(data_total) - len(data_set) - 60:].values
test_inputs.shape
# Out:
# (1295,)

# %%
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)

# %%
test_features = []
for i in range(60, 89):
    test_features.append(test_inputs[i-60:i, 0])

# %%
test_features = np.array(test_features)
test_features = np.reshape(test_features, (test_features.shape[0], test_features.shape[1], 1))
test_features.shape
# Out:
# (29, 60, 1)

# %%
predictions = model.predict(test_features)
# Out:
# 1/1 [==============================] - 0s 76ms/step

# %%
predictions
# Out:
# array([[[0.25589675],
#         [0.2574544 ],
#         [0.25144637],
#         ...,
#         [0.23587005],
#         [0.23453493],
#         [0.24032043]],
#
#        [[0.2574544 ],
#         [0.25144637],
#         [0.24721852],
#         ...,
#         [0.23453493],
#         [0.24032043],
#         [0.46728972]],
#
#        [[0.25144637],
#         [0.24721852],
#         [0.25723186],
#         ...,
#         [0.24032043],
#         [0.46728972],
#         [0.5073431 ]],
#
#        ...,
#
#        [[0.17356475],
#         [0.17601246],
#         [0.18402314],
#         ...,
#         [0.59635067],
#         [0.58900756],
#         [0.582332  ]],
#
#        [[0.17601246],
#         [0.18402314],
#         [0.18736093],
#         ...,
#         [0.58900756],
#         [0.582332  ],
#         [0.59635067]],
#
#        [[0.18402314],
#         [0.18736093],
#         [0.19247887],
#         ...,
#         [0.582332  ],
#         [0.59635067],
#         [0.57320875]]], dtype=float32)

# %%
x_train = data_set[0:1256]
y_train = data_set[1:1257]
print(x_train.shape)
print(y_train.shape)
# Out:
# (1235, 5)
# (1234, 5)

# %%
x_train
# Out:
#             Date    Open    High     Low    Last
# 0     2018-10-08  208.00  222.25  206.85  216.00
# 1     2018-10-05  217.00  218.60  205.90  210.25
# 2     2018-10-04  223.50  227.80  216.15  217.25
# 3     2018-10-03  230.00  237.50  225.75  226.45
# 4     2018-10-01  234.55  234.60  221.05  230.30
# ...          ...     ...     ...     ...     ...
# 1230  2013-10-14  160.85  161.45  157.70  159.30
# 1231  2013-10-11  161.15  163.45  159.00  159.80
# 1232  2013-10-10  156.00  160.80  155.85  160.30
# 1233  2013-10-09  155.70  158.20  154.15  155.30
# 1234  2013-10-08  157.00  157.80  155.20  155.80
#
# [1235 rows x 5 columns]

# %% [markdown]
# # THE NP.RANDOM.RANDN FUNCTIONS

# %%
np.random.seed(1)
np.random.randn(3, 3)
# Out:
# array([[ 1.62434536, -0.61175641, -0.52817175],
#        [-1.07296862,  0.86540763, -2.3015387 ],
#        [ 1.74481176, -0.7612069 ,  0.3190391 ]])

# %% [markdown]
# # DRAW A SINGLE FORM THE NORMAL DISTRIBUTION

# %%
np.random.normal(1)
# Out:
# 0.7506296245225899

# %% [markdown]
# # DRAW A 5 NUMBER FROM THE NORMAL DISTRIBUTION

# %%
np.random.normal(5)
# Out:
# 6.4621079370449745

# %%
np.random.seed(42)
np.random.normal(size = 1000, scale = 100).std()
# Out:
# 97.87262077473541

# %% [markdown]
# # PLOTTING RESULT

# %%
plt.figure(figsize=(18,6))
plt.title("stock market price predic")
plt.plot(data_testing_complete['Close'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Total Trade Quantity',fontsize=18)
plt.show()

# %%
#Analyze the closing prices from dataframe:
data_set["Date"]=pd.to_datetime(data_set.Date)
data_set.index=data_set['Date']
#data_set.head()

# %%
plt.figure(figsize=(20,10))
plt.plot(data_set["Open"],label='ClosePriceHist')

# %%
plt.figure(figsize=(12,6))
plt.plot(data_set['Date'])
plt.xlabel('Turnover (Lacs)',fontsize=18)
plt.ylabel('Total Trade Quantity',fontsize=18)
plt.show()

# %%
#Analyze the closing prices from dataframe:
data_set["Turnover (Lacs)"]=pd.to_datetime(data_set.Date)
data_set.index=data_set['Turnover (Lacs)']
#data_set.head()

# %%
plt.figure(figsize=(20,10))
plt.plot(data_set["Turnover (Lacs)"],label='ClosePriceHist')
